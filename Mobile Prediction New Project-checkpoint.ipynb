# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_iris

# %% [markdown]
# # Import the Data Set

# %%
mobile_prediction_data=pd.read_csv("C:\\Users\\admin\\Desktop\\MobileRatePrediction\\Processed_Flipdata - Processed_Flipdata.csv")
mobile_prediction_data
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %% [markdown]
# # Count Head

# %%
mobile_prediction_data.head()
# Out:
#    Unnamed: 0            Model        Colour  Memory  RAM  Battery_  \
# 0           0  Infinix SMART 7   Night Black      64    4      6000
# 1           1  Infinix SMART 7    Azure Blue      64    4      6000
# 2           2     MOTOROLA G32  Mineral Gray     128    8      5000
# 3           3         POCO C50    Royal Blue      32    2      5000
# 4           4  Infinix HOT 30i      Marigold     128    8      5000
#
#   Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0        13MP          5MP        1          16.76
# 1        13MP          5MP        1          16.76
# 2        50MP         16MP        0          16.64
# 3         8MP          5MP        0          16.56
# 4        50MP          5MP        1          16.76
#
#                    Processor_   Prize
# 0  Unisoc Spreadtrum SC9863A1   7,299
# 1  Unisoc Spreadtrum SC9863A1   7,299
# 2     Qualcomm Snapdragon 680  11,999
# 3          Mediatek Helio A22   5,649
# 4                         G37   8,999

# %%
#Find the shape of data set
mobile_prediction_data.shape
# Out:
# (541, 12)

# %%
#Find the dimantion of data set
mobile_prediction_data.ndim
# Out:
# 2

# %% [markdown]
# # Find the columns of Data Set

# %%
mobile_prediction_data.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %% [markdown]
# # Describe the Data

# %%
mobile_prediction_data.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %% [markdown]
# # Find the null Value in Data Set

# %%
mobile_prediction_data.isnull().sum().to_dict()
# Out:
# {'Unnamed: 0': 0,
#  'Model': 0,
#  'Colour': 0,
#  'Memory': 0,
#  'RAM': 0,
#  'Battery_': 0,
#  'Rear Camera': 0,
#  'Front Camera': 0,
#  'AI Lens': 0,
#  'Mobile Height': 0,
#  'Processor_': 0,
#  'Prize': 0}

# %% [markdown]
# # Remove Unneccery Columns

# %%
mobile_prediction_data=mobile_prediction_data.drop('Unnamed: 0',axis=1)

# %%
mobile_prediction_data
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 0          Infinix SMART 7     Night Black      64    4      6000        13MP
# 1          Infinix SMART 7      Azure Blue      64    4      6000        13MP
# 2             MOTOROLA G32    Mineral Gray     128    8      5000        50MP
# 3                 POCO C50      Royal Blue      32    2      5000         8MP
# 4          Infinix HOT 30i        Marigold     128    8      5000        50MP
# ..                     ...             ...     ...  ...       ...         ...
# 536  SAMSUNG Galaxy S23 5G           Cream     256    8      3900        50MP
# 537               LAVA Z21            Cyan      32    2      3100         5MP
# 538         Tecno Spark 8T  Turquoise Cyan      64    4      5000        50MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000        50MP
# 540               OPPO A77        Sky Blue     128    4      5000        50MP
#
# ...

# %%
mobile_prediction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          541 non-null    object
#  1   Colour         541 non-null    object
#  2   Memory         541 non-null    int64
#  3   RAM            541 non-null    int64
#  4   Battery_       541 non-null    int64
#  5   Rear Camera    541 non-null    object
#  6   Front Camera   541 non-null    object
#  7   AI Lens        541 non-null    int64
#  8   Mobile Height  541 non-null    float64
#  9   Processor_     541 non-null    object
#  10  Prize          541 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 46.6+ KB

# %% [markdown]
# # Find the Unique Value

# %%
mobile_prediction_data["Model"].unique()
# Out:
# array(['Infinix SMART 7', 'MOTOROLA G32', 'POCO C50', 'Infinix HOT 30i',
#        'REDMI 10', 'SAMSUNG Galaxy F13', 'SAMSUNG Galaxy F04', 'POCO C51',
#        'MOTOROLA e13', 'vivo T2x 5G', 'Infinix Smart 7 HD', 'REDMI A1+',
#        'POCO C55', 'MOTOROLA g13', 'POCO M4 5G', 'MOTOROLA e32',
#        'vivo T2 5G', 'MOTOROLA G62 5G', 'POCO M5', 'realme C33 2023',
#        'SAMSUNG Galaxy F14 5G', 'MOTOROLA g73 5G', 'realme C30',
#        'POCO X5 5G', 'POCO M4 Pro', 'REDMI 11 Prime', 'realme C55',
#        'realme 10 Pro 5G', 'Micromax IN 2C', 'POCO M4 Pro 5G',
#        'realme Narzo 30 Pro 5G', 'micromax 2', 'Infinix Note 12 Pro 5G',
#        'SAMSUNG Galaxy F23 5G', 'micromax', 'MOTOROLA Edge 40',
#        'micromax 1', 'realme Narzo 30', 'Infinix NOTE 12i', 'realme 10',
#        'realme 8i', 'Micromax 3', 'Google Pixel 6a', 'Infinix HOT 20 5G',
#        'realme GT 2', 'REDMI Note 12', 'REDMI Note 12 5G', 'micromax 3',
#        'SAMSUNG Galaxy M04', 'REDMI K50i 5G', 'MOTOROLA e40',
# ...

# %% [markdown]
# # Value Count

# %%
mobile_prediction_data['Model'].value_counts()
# Out:
# Model
# vivo Y16                 9
# realme C55               9
# SAMSUNG Galaxy A14 5G    9
# REDMI Note 12 Pro 5G     9
# vivo T1 44W              8
#                         ..
# vivo Y1s                 1
# OnePlus Nord             1
# Micromax 3               1
# vivo Y33s                1
# OPPO A77                 1
# Name: count, Length: 187, dtype: int64

# %%
#Converting a columns prize stored as string into string
mobile_prediction_data["Prize"]=mobile_prediction_data["Prize"].str.replace(r'\D', "").str.replace(",","")
mobile_prediction_data["Prize"]=mobile_prediction_data["Prize"].astype(int)
print(mobile_prediction_data.head())
# Out:
#              Model        Colour  Memory  RAM  Battery_ Rear Camera  \
# 0  Infinix SMART 7   Night Black      64    4      6000        13MP
# 1  Infinix SMART 7    Azure Blue      64    4      6000        13MP
# 2     MOTOROLA G32  Mineral Gray     128    8      5000        50MP
# 3         POCO C50    Royal Blue      32    2      5000         8MP
# 4  Infinix HOT 30i      Marigold     128    8      5000        50MP
#
#   Front Camera  AI Lens  Mobile Height                  Processor_  Prize
# 0          5MP        1          16.76  Unisoc Spreadtrum SC9863A1   7299
# 1          5MP        1          16.76  Unisoc Spreadtrum SC9863A1   7299
# 2         16MP        0          16.64     Qualcomm Snapdragon 680  11999
# 3          5MP        0          16.56          Mediatek Helio A22   5649
# 4          5MP        1          16.76                         G37   8999

# %%
mobile_prediction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          541 non-null    object
#  1   Colour         541 non-null    object
#  2   Memory         541 non-null    int64
#  3   RAM            541 non-null    int64
#  4   Battery_       541 non-null    int64
#  5   Rear Camera    541 non-null    object
#  6   Front Camera   541 non-null    object
#  7   AI Lens        541 non-null    int64
#  8   Mobile Height  541 non-null    float64
#  9   Processor_     541 non-null    object
#  10  Prize          541 non-null    int32
# dtypes: float64(1), int32(1), int64(4), object(5)
# memory usage: 44.5+ KB

# %%
mobile_prediction_data.isnull()
# Out:
#      Model  Colour  Memory    RAM  Battery_  Rear Camera  Front Camera  \
# 0    False   False   False  False     False        False         False
# 1    False   False   False  False     False        False         False
# 2    False   False   False  False     False        False         False
# 3    False   False   False  False     False        False         False
# 4    False   False   False  False     False        False         False
# ..     ...     ...     ...    ...       ...          ...           ...
# 536  False   False   False  False     False        False         False
# 537  False   False   False  False     False        False         False
# 538  False   False   False  False     False        False         False
# 539  False   False   False  False     False        False         False
# 540  False   False   False  False     False        False         False
#
#      AI Lens  Mobile Height  Processor_  Prize
# 0      False          False       False  False
# ...

# %% [markdown]
# # Find the null  value in whhole Data Set

# %%
mobile_prediction_data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Dublicate rows based on columns

# %%
duplicate_rows_mobile=mobile_prediction_data[mobile_prediction_data.duplicated()]
print("duplicate_rows_mobile: ")
print(duplicate_rows_mobile)
# Out:
# duplicate_rows_mobile:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 27             vivo T2x 5G     Marine Blue     128    6      5000        50MP
# 48            MOTOROLA e32     Arctic Blue      64    4      5000        50MP
# 91   SAMSUNG Galaxy F14 5G   B.A.E. Purple     128    4      6000        50MP
# 132  SAMSUNG Galaxy F14 5G       OMG Black     128    6      6000        50MP
# 247              redmi min             M3)      16    4      1000         0MP
# 344         Tecno Spark 9T  Turquoise Cyan      64    4      5000        50MP
# 352         POCO X4 Pro 5G     Laser Black     128    8      5000        64MP
# 424            realme C30s    Stripe Black      64    4      5000         8MP
# 437           vivo Y100 5G    Pacific Blue     128    8      4500        64MP
# 480               POCO C31      Royal Blue      64    4      5000        13MP
#
#     Front Camera  AI Lens  Mobile Height                       Processor_  \
# ...

# %%
duplicate_rows_mobile
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 27             vivo T2x 5G     Marine Blue     128    6      5000        50MP
# 48            MOTOROLA e32     Arctic Blue      64    4      5000        50MP
# 91   SAMSUNG Galaxy F14 5G   B.A.E. Purple     128    4      6000        50MP
# 132  SAMSUNG Galaxy F14 5G       OMG Black     128    6      6000        50MP
# 247              redmi min             M3)      16    4      1000         0MP
# 344         Tecno Spark 9T  Turquoise Cyan      64    4      5000        50MP
# 352         POCO X4 Pro 5G     Laser Black     128    8      5000        64MP
# 424            realme C30s    Stripe Black      64    4      5000         8MP
# 437           vivo Y100 5G    Pacific Blue     128    8      4500        64MP
# 480               POCO C31      Royal Blue      64    4      5000        13MP
#
#     Front Camera  AI Lens  Mobile Height                       Processor_  \
# ...

# %% [markdown]
# # Convert Catorigal Value into Numerical

# %%
#Label Encoding
# Import label encoder 
from sklearn import preprocessing 
  
 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Rear Camera'. 
duplicate_rows_mobile['Rear Camera']= label_encoder.fit_transform(duplicate_rows_mobile['Rear Camera']) 
  
duplicate_rows_mobile['Rear Camera'].unique()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_5992\1581220655.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_rows_mobile['Rear Camera']= label_encoder.fit_transform(duplicate_rows_mobile['Rear Camera'])
# array([2, 0, 3, 4, 1])

# %%
 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Model'. 
duplicate_rows_mobile['Model']= label_encoder.fit_transform(duplicate_rows_mobile['Model']) 
  
duplicate_rows_mobile['Model'].unique()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_5992\2834171707.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_rows_mobile['Model']= label_encoder.fit_transform(duplicate_rows_mobile['Model'])
# array([7, 0, 3, 6, 4, 2, 5, 8, 1])

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Front Camera'. 
duplicate_rows_mobile['Front Camera']= label_encoder.fit_transform(duplicate_rows_mobile['Front Camera']) 
  
duplicate_rows_mobile['Front Camera'].unique()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_5992\718324426.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_rows_mobile['Front Camera']= label_encoder.fit_transform(duplicate_rows_mobile['Front Camera'])
# array([4, 1, 0, 2, 3])

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Processor_ '. 
duplicate_rows_mobile['Processor_']= label_encoder.fit_transform(duplicate_rows_mobile['Processor_']) 
  
duplicate_rows_mobile['Processor_'].unique()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_5992\3822308530.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_rows_mobile['Processor_']= label_encoder.fit_transform(duplicate_rows_mobile['Processor_'])
# array([0, 5, 1, 7, 3, 6, 8, 4, 2])

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Processor_ '. 
duplicate_rows_mobile['Colour']= label_encoder.fit_transform(duplicate_rows_mobile['Colour']) 
  
duplicate_rows_mobile['Colour'].unique()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_5992\4011567432.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_rows_mobile['Colour']= label_encoder.fit_transform(duplicate_rows_mobile['Colour'])
# array([4, 0, 1, 5, 3, 9, 2, 8, 6, 7])

# %% [markdown]
# # Now the Whole Data set convert into Integer Value

# %%
duplicate_rows_mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 27 to 480
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          10 non-null     int32
#  1   Colour         10 non-null     int32
#  2   Memory         10 non-null     int64
#  3   RAM            10 non-null     int64
#  4   Battery_       10 non-null     int64
#  5   Rear Camera    10 non-null     int32
#  6   Front Camera   10 non-null     int32
#  7   AI Lens        10 non-null     int64
#  8   Mobile Height  10 non-null     float64
#  9   Processor_     10 non-null     int32
#  10  Prize          10 non-null     int32
# dtypes: float64(1), int32(6), int64(4)
# memory usage: 720.0 bytes

# %%
duplicate_rows_mobile
# Out:
#      Model  Colour  Memory  RAM  Battery_  Rear Camera  Front Camera  AI Lens  \
# 27       7       4     128    6      5000            2             4        0
# 48       0       0      64    4      5000            2             4        0
# 91       3       1     128    4      6000            2             1        0
# 132      3       5     128    6      6000            2             1        0
# 247      6       3      16    4      1000            0             0        0
# 344      4       9      64    4      5000            2             4        0
# 352      2       2     128    8      5000            3             2        0
# 424      5       8      64    4      5000            4             3        0
# 437      8       6     128    8      4500            3             2        0
# 480      1       7      64    4      5000            1             3        0
#
#      Mobile Height  Processor_  Prize
# 27           16.71           0  13999
# ...

# %% [markdown]
# # Shape of After Encoding

# %%
duplicate_rows_mobile.shape
# Out:
# (10, 11)

# %%
duplicate_rows_mobile.head(20)
# Out:
#      Model  Colour  Memory  RAM  Battery_  Rear Camera  Front Camera  AI Lens  \
# 27       7       4     128    6      5000            2             4        0
# 48       0       0      64    4      5000            2             4        0
# 91       3       1     128    4      6000            2             1        0
# 132      3       5     128    6      6000            2             1        0
# 247      6       3      16    4      1000            0             0        0
# 344      4       9      64    4      5000            2             4        0
# 352      2       2     128    8      5000            3             2        0
# 424      5       8      64    4      5000            4             3        0
# 437      8       6     128    8      4500            3             2        0
# 480      1       7      64    4      5000            1             3        0
#
#      Mobile Height  Processor_  Prize
# 27           16.71           0  13999
# ...

# %%
Mobile_Price=duplicate_rows_mobile.copy()

# %%
Mobile_Price.boxplot(column = "Prize")
plt.show()

# %%
import seaborn as sns

# %%
Mobile_Price.boxplot(column = "Memory")
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
Mobile_Price.columns
# Out:
# Index(['Model', 'Colour', 'Memory', 'RAM', 'Battery_', 'Rear Camera',
#        'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_', 'Prize'],
#       dtype='object')

# %% [markdown]
# # Feature Selection algorithms

# %%
from sklearn.feature_selection import SelectKBest, f_regression

x = Mobile_Price[["Memory", "RAM", "Battery_", "Rear Camera", "Front Camera", "AI Lens", "Processor_"]]  
y = Mobile_Price["Prize"] 

# Define the number of features (k) you want to select
k = 5  # You need to define the value of k

# Initialize SelectKBest with f_regression score function
selector = SelectKBest(score_func=f_regression, k=k)

# Fit and transform the feature selector
x_selected = selector.fit_transform(x, y)

# Get the selected features
selected_features = x.columns[selector.get_support()]

print("Selected features:")
print(selected_features)
# Out:
# Selected features:
# Index(['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Processor_'], dtype='object')

# %% [markdown]
# # Split the Data set into training ad test set

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_selected, y, test_size=0.2, random_state=42)
# test_size=0.2 means 20% of the data will be used for testing, adjust as needed
# Now you have x_train, x_test (features) and y_train, y_test (target) for training and testing respectively
print("Traing set shape:",x_train.shape,y_train.shape)
print("Testing set shape:",x_test.shape,y_test.shape)
# Out:
# Traing set shape: (8, 5) (8,)
# Testing set shape: (2, 5) (2,)

# %% [markdown]
# # Linear Regression Model and mean squred error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model on the training data
model.fit(x_train, y_train)

# Predict the target values for the testing set
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 25341874.5075358

# %% [markdown]
# # Decision Tree Regration

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Initialize the Decision Tree Regression model
tree_model = DecisionTreeRegressor(random_state=42)

# Train the model on the training data
tree_model.fit(x_train, y_train)

# Predict the target values for the testing set
y_pred_tree = tree_model.predict(x_test)

# Evaluate the model
mse_tree = mean_squared_error(y_test, y_pred_tree)
print("Decision Tree Mean Squared Error:", mse_tree)
# Out:
# Decision Tree Mean Squared Error: 10958340.5

# %% [markdown]
# # Import Random Regression Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initialize the Random Forest Regression model
forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model on the training data
forest_model.fit(x_train, y_train)

# Predict the target values for the testing set
y_pred_forest = forest_model.predict(x_test)

# Evaluate the model
mse_forest = mean_squared_error(y_test, y_pred_forest)
print("Random Forest Mean Squared Error:", mse_forest)
# Out:
# Random Forest Mean Squared Error: 25346782.387399998

# %% [markdown]
# # Evaluate Model Perfomance

# %%
# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred_forest)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred_forest)

# R-squared (R2)
r2 = r2_score(y_test, y_pred_forest)

print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 25346782.387399998
# Root Mean Squared Error: 5034.558807621577
# Mean Absolute Error: 4258.55
# R-squared: 0.603956525196875

# %% [markdown]
# # visulize Predicted vs actual price

# %%
import matplotlib.pyplot as plt

def plot_predictions(model, x_test, y_test, model_name):
    y_pred = model.predict(x_test)
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred, alpha=0.5)
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], "r.")
    plt.xlabel("Actual price")
    plt.ylabel("Predicted price")
    plt.title(f'{model_name} - Predicted vs. Actual')
    plt.show()

# Call the function
plot_predictions(forest_model, x_test, y_test, "Random Forest Regression")

# %% [markdown]
# # Visualizing Feature Importance

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_feature_importance(model, feature_names, model_name):
    importances = model.feature_importances_  # Assuming model has attribute feature_importances_
    indices = np.argsort(importances)[::-1]
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(feature_names)), importances[indices], align="center")
    plt.xticks(range(len(feature_names)), [feature_names[i] for i in indices], rotation=45)
    plt.xlabel("Feature")
    plt.ylabel("Importance")
    plt.title(f'{model_name} - Feature Importances')
    plt.show()
